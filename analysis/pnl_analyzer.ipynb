# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "../data/results/round_1_mwa_13.csv"
prices_df = pd.read_csv(filename, sep=";", index_col=["timestamp"], usecols=["timestamp","product","profit_and_loss"])

# %%
prices_df
# Out:
#            product  profit_and_loss
# timestamp
# 0           PEARLS         0.000000
# 0          BANANAS         0.000000
# 100         PEARLS         0.000000
# 100        BANANAS       -17.605469
# 200         PEARLS         2.000000
# ...            ...              ...
# 99700       PEARLS       462.000000
# 99800       PEARLS       462.000000
# 99800      BANANAS       270.183594
# 99900      BANANAS       270.003906
# 99900       PEARLS       462.000000
#
# [2000 rows x 2 columns]

# %%
bananas_df = prices_df[prices_df["product"] == "BANANAS"]
pearls_df = prices_df[prices_df["product"] == "PEARLS"]

# %%
prices_df.plot()
bananas_df.plot()
pearls_df.plot()
# Out:
# <Axes: xlabel='timestamp'>
